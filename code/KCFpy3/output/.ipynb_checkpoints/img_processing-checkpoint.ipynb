# %%
import cv2
import numpy as np
from PIL import Image

import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# The history saving thread hit an unexpected error (OperationalError('unable to open database file')).History will not be written to the database.
# Exception in thread IPythonHistorySavingThread:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/site-packages/IPython/core/history.py", line 834, in run
#   File "</usr/local/lib/python3.7/site-packages/decorator.py:decorator-gen-23>", line 2, in writeout_cache
#   File "/usr/local/lib/python3.7/site-packages/IPython/core/history.py", line 58, in needs_sqlite
#   File "/usr/local/lib/python3.7/site-packages/IPython/core/history.py", line 780, in writeout_cache
#   File "/usr/local/lib/python3.7/site-packages/IPython/core/history.py", line 764, in _writeout_input_cache
# sqlite3.OperationalError: unable to open database file
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/site-packages/ipykernel/iostream.py", line 97, in _event_pipe
# AttributeError: '_thread._local' object has no attribute 'event_pipe'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python/3.7.4/Frameworks/Python.framework/Versions/3.7/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#   File "</usr/local/lib/python3.7/site-packages/decorator.py:decorator-gen-24>", line 2, in run
#   File "/usr/local/lib/python3.7/site-packages/IPython/core/history.py", line 58, in needs_sqlite
#   File "/usr/local/lib/python3.7/site-packages/IPython/core/history.py", line 837, in run
#   File "/usr/local/lib/python3.7/site-packages/ipykernel/iostream.py", line 400, in write
#   File "/usr/local/lib/python3.7/site-packages/ipykernel/iostream.py", line 203, in schedule
#   File "/usr/local/lib/python3.7/site-packages/ipykernel/iostream.py", line 101, in _event_pipe
#   File "/usr/local/lib/python3.7/site-packages/zmq/sugar/context.py", line 146, in socket
#   File "/usr/local/lib/python3.7/site-packages/zmq/sugar/socket.py", line 59, in __init__
#   File "zmq/backend/cython/socket.pyx", line 328, in zmq.backend.cython.socket.Socket.__init__
# zmq.error.ZMQError: Too many open files
# Unhandled exception in thread started by <bound method Thread._bootstrap of <HistorySavingThread(IPythonHistorySavingThread, started 123145355149312)>>

# %%
def get_concat_h(im1, im2):
    dst = Image.new('RGB', (im1.width + im2.width + 100, im1.height))
    dst.paste(im1, (0, 0))
    dst.paste(im2, (im1.width + 100, 0))
    return dst

def get_concat_v(im1, im2):
    dst = Image.new('RGB', (im1.width, im1.height + im2.height))
    dst.paste(im1, (0, 0))
    dst.paste(im2, (0, im1.height))
    return dst

# %%
def get_img_list(n_start, n_end):
    img_list=[]
    for i in range(n_start, n_end+1):
        img_name = "./chaplin_kcf/chaplin_kcf"+str(int(i))+".jpg"
        img = Image.open(img_name)
        img_list.append(img)
    return img_list

def concat_h(n_start=0, n_end=100):
    img_list = get_img_list(n_start, n_end)
    res = img_list[0]
    for i in range(1, len(img_list)):
        res = get_concat_h(res, img_list[i])
    return res

# %%
res = concat_h(n_start=1, n_end=10)
res.save('data/chaplin_kcf_impl_01-10.jpg')
plt.imshow(res)

res = concat_h(n_start=11, n_end=20)
res.save('data/chaplin_kcf_impl_11-20.jpg')
plt.imshow(res)

res = concat_h(n_start=21, n_end=30)
res.save('data/chaplin_kcf_impl_21-30.jpg')
plt.imshow(res)

res = concat_h(n_start=31, n_end=40)
res.save('data/chaplin_kcf_impl_31-40.jpg')
plt.imshow(res)

res = concat_h(n_start=41, n_end=50)
res.save('data/chaplin_kcf_impl_41-50.jpg')
plt.imshow(res)

res = concat_h(n_start=51, n_end=60)
res.save('data/chaplin_kcf_impl_51-60.jpg')
plt.imshow(res)

res = concat_h(n_start=61, n_end=70)
res.save('data/chaplin_kcf_impl_61-70.jpg')
plt.imshow(res)

res = concat_h(n_start=71, n_end=80)
res.save('data/chaplin_kcf_impl_71-80.jpg')
plt.imshow(res)

res = concat_h(n_start=81, n_end=90)
res.save('data/chaplin_kcf_impl_81-90.jpg')
plt.imshow(res)

res = concat_h(n_start=91, n_end=100)
res.save('data/chaplin_kcf_impl_91-100.jpg')
plt.imshow(res)

# %%
im1 = Image.open('./chaplin_kcf/chaplin_kcf1.jpg')
plt.imshow(im1)

# %%
img1 = Image.open('data/chaplin_kcf_impl_01-10.jpg')
img2 = Image.open('data/chaplin_kcf_impl_11-20.jpg')
img3 = Image.open('data/chaplin_kcf_impl_21-30.jpg')
img4 = Image.open('data/chaplin_kcf_impl_31-40.jpg')
img5 = Image.open('data/chaplin_kcf_impl_41-50.jpg')
img6 = Image.open('data/chaplin_kcf_impl_51-60.jpg')
img7 = Image.open('data/chaplin_kcf_impl_61-70.jpg')
img8 = Image.open('data/chaplin_kcf_impl_71-80.jpg')
img9 = Image.open('data/chaplin_kcf_impl_81-90.jpg')
img10 = Image.open('data/chaplin_kcf_impl_91-100.jpg')

res = img1
res = get_concat_v(res, img2)
res = get_concat_v(res, img3)
res = get_concat_v(res, img4)
res = get_concat_v(res, img5)
res = get_concat_v(res, img6)
res = get_concat_v(res, img7)
res = get_concat_v(res, img8)
res = get_concat_v(res, img9)
res = get_concat_v(res, img10)

plt.imshow(res)

# %%
res.save('./data/chaplin_kcf_impl.jpg')
